# %%
import rerun as rr
from rerun.notebook import Viewer
# Out:
# DEV ENVIRONMENT DETECTED! Re-importing rerun from: /Users/aedm/w/rerun1/rerun_py/rerun_sdk
# Starting asset server due to RERUN_NOTEBOOK_ASSET=serve-local
# Loading assets into memory…
# Serving rerun notebook assets at http://127.0.0.1:50689

# %% [markdown]
# # Auth demo

# %%
rr.auth.status()
# Out:
# {'authenticated': False}

# %%
import rerun_bindings
rerun_bindings.get_thread_local_blueprint_recording()
# Out:
# get_thread_local_blueprint_recording+++

# %%
from rerun_bindings import OauthLoginFlow
flow = OauthLoginFlow()
flow
# Out:
# PyOauthLoginFlow::new
# PyOauthLoginFlow::new runtime started
# OauthLoginFlow::new starting server
# OauthLoginFlow::newhttps://api.workos.com/user_management/authorize?response_type=code&client_id=client_01JZ3JVR1PEVQMS73V86MC4CE2&redirect_uri=http://127.0.0.1:17340/logged-in&state=02e4bfd4-4769-40bb-808e-421c1d5cd003&provider=authkit&code_challenge=-xVDwfnrd_tREKNlxX9vIsywzopQw7qobjZfmIeu1IU&code_challenge_method=S256

# %%
flow.login_url()
# Out:
# PyOauthLoginFlow::login_url
# 'https://api.workos.com/user_management/authorize?response_type=code&client_id=client_01JZ3JVR1PEVQMS73V86MC4CE2&redirect_uri=http://127.0.0.1:17340/logged-in&state=02e4bfd4-4769-40bb-808e-421c1d5cd003&provider=authkit&code_challenge=-xVDwfnrd_tREKNlxX9vIsywzopQw7qobjZfmIeu1IU&code_challenge_method=S256'

# %%
flow.get_credentials()
# Out:
# PyOauthLoginFlow::get_credentials
# OauthLoginFlow::get_credentials
# OauthLoginFlow::get_credentials code: 01KADZNJZM2C6BHD5N2CYF5XXA
# Success! You are now logged in as gabor@rerun.io
# Rerun will automatically use the credentials stored on your machine.
# 'eyJhbGciOiJSUzI1NiIsImtpZCI6InNzb19vaWRjX2tleV9wYWlyXzAxSlozSlZRWlpWUjk2U1czMEdQRURYTlZFIn0.....fFZEseiYLN_enJN_pRlgzpvoNQVzLkczK7k1AU7Salk6cMngdk3APzqSZIrw1FyRp6sYBXFJZEzH2yYhyWAQMi3n-7Us1JTDFAK4nc2ECLofio1CDBDwICDBklufiR5-BcdcU377ztlgXckmvn5MLKyZ0SxPvdr23NaBS3XZxxFwHhn0Z0cei8yl1tQMNvzm3u4ZwHEJWslAeTBjwJjnlPT-uGXzzHNLmsyGyyURwZLg1rVZStnV_hrB2wF2e21UrJV-uI02HhRr_yYaunTEHKdzmRvCILSW4xjq3CQIN_NoywtQeBdQSx48txzJ43zNaiTiExGBhXNhLIuctZn3XQ'

# %%
rerun_bindings.boo()
# Out:
# boo!!!

# %%
Viewer(width=1000, height=600).display()
# Out:
# Viewer()

# %% [markdown]
# ### Log in to WorkOS

# %%
rr.auth.login()
# Out:
# Starting auth callback server on http://localhost:17340
#  * Serving Flask app 'rerun.auth'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:17340
# Press CTRL+C to quit
# 127.0.0.1 - - [14/Nov/2025 16:08:13] "GET /status HTTP/1.1" 200 -
# ✓ Auth callback server started.
# 127.0.0.1 - - [14/Nov/2025 16:08:13] "GET /login HTTP/1.1" 302 -
# 127.0.0.1 - - [14/Nov/2025 16:08:15] "GET /logged-in?code=01KA1EHW4045M3VXHR9WC30DY8&state=db1dc7a6-3f5b-428b-ac71-170814f5065b HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 16:08:17] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ### See login state

# %%
rr.auth.status()
# Out:
# {'authenticated': True,
#  'profile': {'id': 'user_01K9543701JP6JVDXJEF50N820',
#   'email': 'gabor@rerun.io',
#   'first_name': 'Gábor',
#   'last_name': 'Gyebnár'},
#  'has_token': True}

# %% [markdown]
# ### Propagate credentials to the viewer

# %%
viewer = Viewer(width=1000, height=600)
viewer.display()
# Out:
# Viewer()
