# %%
import rerun as rr
from rerun.notebook import Viewer
# Out:
# DEV ENVIRONMENT DETECTED! Re-importing rerun from: /Users/aedm/w/rerun1/rerun_py/rerun_sdk
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import rerun as rr
#       2 from rerun.notebook import Viewer
#
# File ~/w/rerun1/rerun_py/rerun/__init__.py:39
#      36 sys.path.insert(0, str(real_path))
#      38 del sys.modules["rerun"]
# ---> 39 sys.modules["rerun"] = __import__("rerun")
#
# File ~/w/rerun1/rerun_py/rerun_sdk/rerun/__init__.py:121
#      74 from .archetypes import (
#      75     AnnotationContext as AnnotationContext,
#      76     Arrows2D as Arrows2D,
#    (...)    116     ViewCoordinates as ViewCoordinates,
#     117 )
#     118 from .archetypes.boxes2d_ext import (
#     119     Box2DFormat as Box2DFormat,
#     120 )
# --> 121 from .auth import (
#     122     Auth as Auth,
#     123     login_with_browser as login_with_browser,
#     124 )
#     125 from .components import (
#     126     AlbedoFactor as AlbedoFactor,
#     127     GraphEdge as GraphEdge,
#    (...)    135     VideoCodec as VideoCodec,
#     136 )
#     137 from .datatypes import (
#     138     Angle as Angle,
#     139     AnnotationInfo as AnnotationInfo,
#    (...)    151     VisibleTimeRange as VisibleTimeRange,
#     152 )
#
# ImportError: cannot import name 'Auth' from 'rerun.auth' (/Users/aedm/w/rerun1/rerun_py/rerun_sdk/rerun/auth.py)

# %%
rr.auth.status()

# %%
rr.login_with_browser()

# %%
CATALOG_URL="rerun://sandbox.redap.rerun.io"
DATASET="droid:raw"

client = rr.catalog.CatalogClient(CATALOG_URL)
dataset = client.get_dataset_entry(name=DATASET)
partitions = dataset.partition_table().df()
print(f"There are {partitions.count()} episodes in '{DATASET}'")

# %%
EPISODE = 'ILIAD_5e938e3b_2023_07_20_10h_40m_10s'
Viewer(url=dataset.partition_url(EPISODE))

# %%
import rerun_bindings
rerun_bindings.get_thread_local_blueprint_recording()

# %%
from rerun_bindings import OauthLoginFlow
flow = OauthLoginFlow()
flow

# %%
flow.login_url()

# %%
flow.get_credentials()

# %%
rerun_bindings.boo()

# %%
Viewer(width=1000, height=600).display()

# %% [markdown]
# ### Log in to WorkOS

# %%
rr.auth.login()

# %% [markdown]
# ### See login state

# %%
rr.auth.status()

# %% [markdown]
# ### Propagate credentials to the viewer

# %%
viewer = Viewer(width=1000, height=600)
viewer.display()
