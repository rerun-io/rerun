# %%
import rerun as rr
from rerun.notebook import Viewer
# Out:
# DEV ENVIRONMENT DETECTED! Re-importing rerun from: /Users/aedm/w/rerun1/rerun_py/rerun_sdk
# Starting asset server due to RERUN_NOTEBOOK_ASSET=serve-local
# Loading assets into memory…
# Serving rerun notebook assets at http://127.0.0.1:49810

# %%
rr.login_with_browser()
# Out:
# Please open the following URL in your browser if it doesn't open automatically: https://api.workos.com/user_management/authorize?response_type=code&client_id=client_01JZ3JVR1PEVQMS73V86MC4CE2&redirect_uri=http://127.0.0.1:17340/logged-in&state=dcbedc1a-b224-42d0-8cbe-67f1b22fdb40&provider=authkit&code_challenge=-l7OA_qk8yd_vrbb74TYmsWptBo6IraoeM3jX0MKhrg&code_challenge_method=S256
# PyOauthLoginFlow::new
# OauthLoginFlow::new starting server
# OauthLoginFlow::new https://api.workos.com/user_management/authorize?response_type=code&client_id=client_01JZ3JVR1PEVQMS73V86MC4CE2&redirect_uri=http://127.0.0.1:17340/logged-in&state=dcbedc1a-b224-42d0-8cbe-67f1b22fdb40&provider=authkit&code_challenge=-l7OA_qk8yd_vrbb74TYmsWptBo6IraoeM3jX0MKhrg&code_challenge_method=S256
# PyOauthLoginFlow::new runtime started: https://api.workos.com/user_management/authorize?response_type=code&client_id=client_01JZ3JVR1PEVQMS73V86MC4CE2&redirect_uri=http://127.0.0.1:17340/logged-in&state=dcbedc1a-b224-42d0-8cbe-67f1b22fdb40&provider=authkit&code_challenge=-l7OA_qk8yd_vrbb74TYmsWptBo6IraoeM3jX0MKhrg&code_challenge_method=S256
# PyOauthLoginFlow::get_credentials
# Storing credentials NATIVE: path="/Users/aedm/Library/Application Support/rerun/credentials.json", data="{\n  \"user\": {\n    \"id\": \"user_01K9543701JP6JVDXJEF50N820\",\n    \"email\": \"gabor@rerun.io\"\n  },\n  \"refresh_token\": \"i3L08CAZzeZS0a0Xx86fTuHYg\",\n  \"access_token\": {\n    \"token\": \"eyJhbGciOiJSUzI1NiIsImtpZCI6InNzb19vaWRjX2tleV9wYWlyXzAxSlozSlZRWlpWUjk2U1czMEdQRURYTlZFIn0.....dhsxiPjw3pSf-3wWxOTMkqsZMb5DcGLppD0NI0wkEg22ubVfDUf_N9TweSPKJv9aSM3XEOdcTy0aUYqvBgt1CCrKJipcMGRS1sr4LZlArbKsXZRAF9hoXb3T5PzodqjYpjKgPfDJ7r5pW1WdJKvDRpEviD8nw9xZgmzuQWFvnniF0WA1FqB1Twgv9uaAVc1LsYzrJGsfqXN_7h1kQ4EpTk9QcXIB1PbPWcsYmF-etURGnJqb2o3tW-lxITBz1vSUc3MXtLDHNkV5M8EtPKBV5JJKWzJBL1iMSGnxjh-Z0FWU4oiCCGINHFFuMijOvnVGYhVP1XiZLcfu_PqbbtCCmA\",\n    \"expires_at\": 1763826644\n  }\n}"
# Success! You are now logged in as gabor@rerun.io
# Rerun will automatically use the credentials stored on your machine.

# %%
CATALOG_URL="rerun://sandbox.redap.rerun.io"
DATASET="droid:raw"

client = rr.catalog.CatalogClient(CATALOG_URL)
dataset = client.get_dataset_entry(name=DATASET)
partitions = dataset.partition_table().df()
print(f"There are {partitions.count()} episodes in '{DATASET}'")
# Out:
# Loading credentials NATIVE: path="/Users/aedm/Library/Application Support/rerun/credentials.json"
# Loaded credentials NATIVE data="{\n  \"user\": {\n    \"id\": \"user_01K9543701JP6JVDXJEF50N820\",\n    \"email\": \"gabor@rerun.io\"\n  },\n  \"refresh_token\": \"i3L08CAZzeZS0a0Xx86fTuHYg\",\n  \"access_token\": {\n    \"token\": \"eyJhbGciOiJSUzI1NiIsImtpZCI6InNzb19vaWRjX2tleV9wYWlyXzAxSlozSlZRWlpWUjk2U1czMEdQRURYTlZFIn0.....dhsxiPjw3pSf-3wWxOTMkqsZMb5DcGLppD0NI0wkEg22ubVfDUf_N9TweSPKJv9aSM3XEOdcTy0aUYqvBgt1CCrKJipcMGRS1sr4LZlArbKsXZRAF9hoXb3T5PzodqjYpjKgPfDJ7r5pW1WdJKvDRpEviD8nw9xZgmzuQWFvnniF0WA1FqB1Twgv9uaAVc1LsYzrJGsfqXN_7h1kQ4EpTk9QcXIB1PbPWcsYmF-etURGnJqb2o3tW-lxITBz1vSUc3MXtLDHNkV5M8EtPKBV5JJKWzJBL1iMSGnxjh-Z0FWU4oiCCGINHFFuMijOvnVGYhVP1XiZLcfu_PqbbtCCmA\",\n    \"expires_at\": 1763826644\n  }\n}"
# There are 2038 episodes in 'droid:raw'

# %%
EPISODE = 'ILIAD_5e938e3b_2023_07_20_10h_40m_10s'
Viewer(url=dataset.partition_url(EPISODE))

# %%
import rerun_bindings
rerun_bindings.get_thread_local_blueprint_recording()

# %%
from rerun_bindings import OauthLoginFlow
flow = OauthLoginFlow()
flow

# %%
flow.login_url()

# %%
flow.get_credentials()

# %%
rerun_bindings.boo()

# %%
Viewer(width=1000, height=600).display()

# %% [markdown]
# ### Log in to WorkOS

# %%
rr.auth.login()

# %% [markdown]
# ### See login state

# %%
rr.auth.status()

# %% [markdown]
# ### Propagate credentials to the viewer

# %%
viewer = Viewer(width=1000, height=600)
viewer.display()
