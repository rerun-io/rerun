# %% [markdown]
# # Exploring Image Data
#
# Starting with the simple sample mcap examples

# %%
import rerun as rr

IMAGE_PATH = "/Users/nick/Downloads/image.rrd"

# %%
rec = rr.dataframe.load_recording(IMAGE_PATH)
print(
    f"Recording: {rec.application_id()}, {rec.recording_id()}"
)
# Out:
# Recording: mcap-image-example.mcap, rec_c17995bfc533480a83980e305f0e4885

# %%
# Mostly a note to future me but it'd be nice if this actually printed out something.
print(rec)
# Out:
# <builtins.Recording object at 0x11f2d2e80>

# %%
print(rec.schema())
# Out:
# Column name: /camera/annotations:circles
# 	Entity path: /camera/annotations
# 	Archetype: foxglove.ImageAnnotations
# 	Component type:
# 	Component: circles
# Column name: /camera/annotations:points
# 	Entity path: /camera/annotations
# 	Archetype: foxglove.ImageAnnotations
# 	Component type:
# 	Component: points
# Column name: /camera/annotations:texts
# 	Entity path: /camera/annotations
# 	Archetype: foxglove.ImageAnnotations
# 	Component type:
# 	Component: texts
# Column name: /camera/annotations:TextLog:level
# 	Entity path: /camera/annotations
# 	Archetype: rerun.archetypes.TextLog
# 	Component type: rerun.components.TextLogLevel
# 	Component: TextLog:level
# Column name: /camera/annotations:TextLog:text
# 	Entity path: /camera/annotations
# 	Archetype: rerun.archetypes.TextLog
# 	Component type: rerun.components.Text
# 	Component: TextLog:text
# Column name: /camera/annotations:id
# 	Entity path: /camera/annotations
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: id
# Column name: /camera/annotations:message_encoding
# 	Entity path: /camera/annotations
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: message_encoding
# Column name: /camera/annotations:metadata
# 	Entity path: /camera/annotations
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: metadata
# Column name: /camera/annotations:topic
# 	Entity path: /camera/annotations
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: topic
# Column name: /camera/annotations:data
# 	Entity path: /camera/annotations
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: data
# Column name: /camera/annotations:encoding
# 	Entity path: /camera/annotations
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: encoding
# Column name: /camera/annotations:name
# 	Entity path: /camera/annotations
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: name
# Column name: /camera/calibration:D
# 	Entity path: /camera/calibration
# 	Archetype: foxglove.CameraCalibration
# 	Component type:
# 	Component: D
# Column name: /camera/calibration:K
# 	Entity path: /camera/calibration
# 	Archetype: foxglove.CameraCalibration
# 	Component type:
# 	Component: K
# Column name: /camera/calibration:P
# 	Entity path: /camera/calibration
# 	Archetype: foxglove.CameraCalibration
# 	Component type:
# 	Component: P
# Column name: /camera/calibration:R
# 	Entity path: /camera/calibration
# 	Archetype: foxglove.CameraCalibration
# 	Component type:
# 	Component: R
# Column name: /camera/calibration:distortion_model
# 	Entity path: /camera/calibration
# 	Archetype: foxglove.CameraCalibration
# 	Component type:
# 	Component: distortion_model
# Column name: /camera/calibration:frame_id
# 	Entity path: /camera/calibration
# 	Archetype: foxglove.CameraCalibration
# 	Component type:
# 	Component: frame_id
# Column name: /camera/calibration:height
# 	Entity path: /camera/calibration
# 	Archetype: foxglove.CameraCalibration
# 	Component type:
# 	Component: height
# Column name: /camera/calibration:timestamp
# 	Entity path: /camera/calibration
# 	Archetype: foxglove.CameraCalibration
# 	Component type:
# 	Component: timestamp
# Column name: /camera/calibration:width
# 	Entity path: /camera/calibration
# 	Archetype: foxglove.CameraCalibration
# 	Component type:
# 	Component: width
# Column name: /camera/calibration:TextLog:level
# 	Entity path: /camera/calibration
# 	Archetype: rerun.archetypes.TextLog
# 	Component type: rerun.components.TextLogLevel
# 	Component: TextLog:level
# Column name: /camera/calibration:TextLog:text
# 	Entity path: /camera/calibration
# 	Archetype: rerun.archetypes.TextLog
# 	Component type: rerun.components.Text
# 	Component: TextLog:text
# Column name: /camera/calibration:id
# 	Entity path: /camera/calibration
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: id
# Column name: /camera/calibration:message_encoding
# 	Entity path: /camera/calibration
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: message_encoding
# Column name: /camera/calibration:metadata
# 	Entity path: /camera/calibration
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: metadata
# Column name: /camera/calibration:topic
# 	Entity path: /camera/calibration
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: topic
# Column name: /camera/calibration:data
# 	Entity path: /camera/calibration
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: data
# Column name: /camera/calibration:encoding
# 	Entity path: /camera/calibration
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: encoding
# Column name: /camera/calibration:name
# 	Entity path: /camera/calibration
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: name
# Column name: /camera/image:frame_id
# 	Entity path: /camera/image
# 	Archetype: foxglove.RawImage
# 	Component type:
# 	Component: frame_id
# Column name: /camera/image:height
# 	Entity path: /camera/image
# 	Archetype: foxglove.RawImage
# 	Component type:
# 	Component: height
# Column name: /camera/image:step
# 	Entity path: /camera/image
# 	Archetype: foxglove.RawImage
# 	Component type:
# 	Component: step
# Column name: /camera/image:timestamp
# 	Entity path: /camera/image
# 	Archetype: foxglove.RawImage
# 	Component type:
# 	Component: timestamp
# Column name: /camera/image:width
# 	Entity path: /camera/image
# 	Archetype: foxglove.RawImage
# 	Component type:
# 	Component: width
# Column name: /camera/image:TextLog:level
# 	Entity path: /camera/image
# 	Archetype: rerun.archetypes.TextLog
# 	Component type: rerun.components.TextLogLevel
# 	Component: TextLog:level
# Column name: /camera/image:TextLog:text
# 	Entity path: /camera/image
# 	Archetype: rerun.archetypes.TextLog
# 	Component type: rerun.components.Text
# 	Component: TextLog:text
# Column name: /camera/image:id
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: id
# Column name: /camera/image:message_encoding
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: message_encoding
# Column name: /camera/image:metadata
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: metadata
# Column name: /camera/image:topic
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: topic
# Column name: /camera/image:data
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: data
# Column name: /camera/image:encoding
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: encoding
# Column name: /camera/image:name
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: name
# Column name: property:RecordingInfo:start_time
# 	Entity path: /__properties
# 	Archetype: rerun.archetypes.RecordingInfo
# 	Component type: rerun.components.Timestamp
# 	Component: RecordingInfo:start_time
# Column name: property:attachment_count
# 	Entity path: /__properties
# 	Archetype: rerun.mcap.Statistics
# 	Component type:
# 	Component: attachment_count
# Column name: property:channel_count
# 	Entity path: /__properties
# 	Archetype: rerun.mcap.Statistics
# 	Component type:
# 	Component: channel_count
# Column name: property:channel_message_counts
# 	Entity path: /__properties
# 	Archetype: rerun.mcap.Statistics
# 	Component type:
# 	Component: channel_message_counts
# Column name: property:chunk_count
# 	Entity path: /__properties
# 	Archetype: rerun.mcap.Statistics
# 	Component type:
# 	Component: chunk_count
# Column name: property:message_count
# 	Entity path: /__properties
# 	Archetype: rerun.mcap.Statistics
# 	Component type:
# 	Component: message_count
# Column name: property:message_end_time
# 	Entity path: /__properties
# 	Archetype: rerun.mcap.Statistics
# 	Component type: rerun.components.Timestamp
# 	Component: message_end_time
# Column name: property:message_start_time
# 	Entity path: /__properties
# 	Archetype: rerun.mcap.Statistics
# 	Component type: rerun.components.Timestamp
# 	Component: message_start_time
# Column name: property:metadata_count
# 	Entity path: /__properties
# 	Archetype: rerun.mcap.Statistics
# 	Component type:
# 	Component: metadata_count
# Column name: property:schema_count
# 	Entity path: /__properties
# 	Archetype: rerun.mcap.Statistics
# 	Component type:
# 	Component: schema_count

# %% [markdown]
# Notes on schema:
# * Generally the overall tagged component layout is nice and makes sense if I'm thinking about it from a topic perspective.
# * The nesting under `TextLog` looks nice but it feels like we should get the same under `mcap.Channel` and `mcap.Schema` (ex. `/camera/image:metadata` -> `/camera/image:Channel:metadata`)
#     * I believe this lack of unique naming also seems to cause a problem in our dataframe extraction. See below where `foxglove.RawImage` `data` and `mcap.Schema` `data` don't both appear to show up

# %%
for component in rec.schema():
    if isinstance(component, rr.dataframe.IndexColumnDescriptor):
        continue
    if "image" in component.entity_path and "data" in component.component:
        print(component)
# Out:
# Column name: /camera/image:metadata
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: metadata
# Column name: /camera/image:data
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: data

# %%
view = rec.view(index="publish_time", contents="/camera/image/**")

# %%
# This looks like a bug because the mcap schema should be static but we query the publish time index above
view.schema()
# Out:
# Column name: /camera/image:frame_id
# 	Entity path: /camera/image
# 	Archetype: foxglove.RawImage
# 	Component type:
# 	Component: frame_id
# Column name: /camera/image:height
# 	Entity path: /camera/image
# 	Archetype: foxglove.RawImage
# 	Component type:
# 	Component: height
# Column name: /camera/image:step
# 	Entity path: /camera/image
# 	Archetype: foxglove.RawImage
# 	Component type:
# 	Component: step
# Column name: /camera/image:timestamp
# 	Entity path: /camera/image
# 	Archetype: foxglove.RawImage
# 	Component type:
# 	Component: timestamp
# Column name: /camera/image:width
# 	Entity path: /camera/image
# 	Archetype: foxglove.RawImage
# 	Component type:
# 	Component: width
# Column name: /camera/image:TextLog:level
# 	Entity path: /camera/image
# 	Archetype: rerun.archetypes.TextLog
# 	Component type: rerun.components.TextLogLevel
# 	Component: TextLog:level
# Column name: /camera/image:TextLog:text
# 	Entity path: /camera/image
# 	Archetype: rerun.archetypes.TextLog
# 	Component type: rerun.components.Text
# 	Component: TextLog:text
# Column name: /camera/image:id
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: id
# Column name: /camera/image:message_encoding
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: message_encoding
# Column name: /camera/image:topic
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Channel
# 	Component type:
# 	Component: topic
# Column name: /camera/image:data
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: data
# Column name: /camera/image:encoding
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: encoding
# Column name: /camera/image:name
# 	Entity path: /camera/image
# 	Archetype: rerun.mcap.Schema
# 	Component type:
# 	Component: name

# %%
batches = view.select()

# %%
next_batch = next(iter(batches))
print(next_batch)
# Out:
# pyarrow.RecordBatch
# log_time: timestamp[ns]
# publish_time: timestamp[ns]
# /camera/image:frame_id: list<item: string>
#   child 0, item: string
# /camera/image:height: list<item: uint32>
#   child 0, item: uint32
# /camera/image:step: list<item: uint32>
#   child 0, item: uint32
# /camera/image:timestamp: list<item: struct<seconds: int64, nanos: int32>>
#   child 0, item: struct<seconds: int64, nanos: int32>
#       child 0, seconds: int64
#       child 1, nanos: int32
# /camera/image:width: list<item: uint32>
#   child 0, item: uint32
# /camera/image:TextLog:level: list<item: string>
#   child 0, item: string
# /camera/image:TextLog:text: list<item: string>
#   child 0, item: string
# /camera/image:id: list<item: uint16>
#   child 0, item: uint16
# /camera/image:message_encoding: list<item: string>
#   child 0, item: string
# /camera/image:topic: list<item: string>
#   child 0, item: string
# /camera/image:data: list<item: binary>
#   child 0, item: binary
# /camera/image:encoding: list<item: string>
#   child 0, item: string
# /camera/image:name: list<item: string>
#   child 0, item: string
# ----
# log_time: [2025-08-01 12:25:45.624517000]
# publish_time: [2025-08-01 12:25:45.624517000]
# /camera/image:frame_id: [["camera"]]
# /camera/image:height: [[128]]
# /camera/image:step: [[384]]
# /camera/image:timestamp: [-- is_valid: all not null
# -- child 0 type: int64
# [1754051145]
# -- child 1 type: int32
# [624517000]]
# /camera/image:width: [[128]]
# /camera/image:TextLog:level: [["WARN"]]
# /camera/image:TextLog:text: [["Unsupported schema for channel: foxglove.RawImage"]]
# /camera/image:id: [[1]]
# ...

# %%
# This looks like our static data
next_batch["/camera/image:data"].flatten()
# Out:
# <pyarrow.lib.BinaryArray object at 0x13c14cfa0>
# [
#   ...
# ]

# %%
static_batches = rec.view(index=None, contents="/camera/image/**").select()

# %%
print(next(iter(static_batches)))
# Out:
# pyarrow.RecordBatch
# log_time: timestamp[ns]
# publish_time: timestamp[ns]
# /camera/image:TextLog:level: list<item: string>
#   child 0, item: string
# /camera/image:TextLog:text: list<item: string>
#   child 0, item: string
# /camera/image:id: list<item: uint16>
#   child 0, item: uint16
# /camera/image:message_encoding: list<item: string>
#   child 0, item: string
# /camera/image:topic: list<item: string>
#   child 0, item: string
# /camera/image:data: list<item: binary>
#   child 0, item: binary
# /camera/image:encoding: list<item: string>
#   child 0, item: string
# /camera/image:name: list<item: string>
#   child 0, item: string
# ----
# log_time: [null]
# publish_time: [null]
# /camera/image:TextLog:level: [["WARN"]]
# /camera/image:TextLog:text: [["Unsupported schema for channel: foxglove.RawImage"]]
# /camera/image:id: [[1]]
# /camera/image:message_encoding: [["protobuf"]]
# /camera/image:topic: [["/camera/image"]]
# /camera/image:data: [[...]]
# /camera/image:encoding: [["protobuf"]]
# /camera/image:name: [["foxglove.RawImage"]]
